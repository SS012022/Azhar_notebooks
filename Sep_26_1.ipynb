# %% [markdown]
# <a href="https://colab.research.google.com/github/SS012022/Azhar_notebooks/blob/main/Sep_26_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
d={"course":["java","python","c","html"],"fee":[2345,4567,5234,2435],"Duration":[30,45,20,30],"discount":[100,np.NaN,50,np.NaN]}

df=pd.DataFrame(d)
df.to_csv("student.csv")
df
# Out:
#    course   fee  Duration  discount
# 0    java  2345        30     100.0
# 1  python  4567        45       NaN
# 2       c  5234        20      50.0
# 3    html  2435        30       NaN

# %%
df["course"][1]=np.nan
df
# Out:
# <ipython-input-11-d66fdd57aa1a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["course"][1]=np.nan
#   course   fee  Duration  discount
# 0   java  2345        30     100.0
# 1    NaN  4567        45       NaN
# 2      c  5234        20      50.0
# 3   html  2435        30       NaN

# %%
df.dropna(axis=0,thresh=2,inplace=True)
df
# Out:
#    course   fee  Duration  discount
# 0    java  2345        30     100.0
# 1  python  4567        45       NaN
# 2       c  5234        20      50.0
# 3    html  2435        30       NaN

# %%
df2=pd.read_csv("student.csv",skiprows=[2])
df2
# Out:
#    Unnamed: 0 course   fee  Duration  discount
# 0           0   java  2345        30     100.0
# 1           2      c  5234        20      50.0
# 2           3   html  2435        30       NaN

# %%
df3=pd.read_csv("student.csv")
df3
# Out:
#    Unnamed: 0  course   fee  Duration  discount
# 0           0    java  2345        30     100.0
# 1           1  python  4567        45       NaN
# 2           2       c  5234        20      50.0
# 3           3    html  2435        30       NaN

# %%
df1=df["discount"].fillna(50)
df1
# Out:
# 0    100.0
# 1     50.0
# 2     50.0
# 3     50.0
# Name: discount, dtype: float64

# %%
df["discount"].fillna(df["discount"].mean(),inplace=True)
df
# Out:
#    course   fee  Duration  discount
# 0    java  2345        30     100.0
# 1  python  4567        45      75.0
# 2       c  5234        20      50.0
# 3    html  2435        30      75.0

# %%
df=pd.read_csv("student.csv")
df
# Out:
#    Unnamed: 0  course   fee  Duration  discount
# 0           0    java  2345        30     100.0
# 1           1  python  4567        45       NaN
# 2           2       c  5234        20      50.0
# 3           3    html  2435        30       NaN

# %%
df["course"][1]=np.nan
df
# Out:
# <ipython-input-20-d66fdd57aa1a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["course"][1]=np.nan
#    Unnamed: 0 course   fee  Duration  discount
# 0           0   java  2345        30     100.0
# 1           1    NaN  4567        45       NaN
# 2           2      c  5234        20      50.0
# 3           3   html  2435        30       NaN

# %%
df.shape
# Out:
# (4, 5)

# %%
df1=df[["course","fee","Duration","discount"]]
df1
# Out:
#   course   fee  Duration  discount
# 0   java  2345        30     100.0
# 1    NaN  4567        45       NaN
# 2      c  5234        20      50.0
# 3   html  2435        30       NaN

# %%
df1.dropna(axis=0,thresh=2,inplace=True)
df1
# Out:
# <ipython-input-43-5d56fb070a80>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.dropna(axis=0,thresh=2,inplace=True)
#   course   fee  Duration  discount
# 0   java  2345        30     100.0
# 1    NaN  4567        45       NaN
# 2      c  5234        20      50.0
# 3   html  2435        30       NaN

# %%
dict={'Subject':['java','python','html',np.nan,np.nan],
      'Duration':['45days',np.nan,'30days',np.nan,np.nan],
      'Fee':[np.nan,122,np.nan,np.nan,np.nan],
      'trainer':['a',np.nan,np.nan,'t',np.nan]}
df1=pd.DataFrame(dict)
df1
# Out:
#   Subject Duration    Fee trainer
# 0    java   45days    NaN       a
# 1  python      NaN  122.0     NaN
# 2    html   30days    NaN     NaN
# 3     NaN      NaN    NaN       t
# 4     NaN      NaN    NaN     NaN

# %%
df1.dropna(axis=0,thresh=2,inplace=True)
df1
# Out:
#   Subject Duration    Fee trainer
# 0    java   45days    NaN       a
# 1  python      NaN  122.0     NaN
# 2    html   30days    NaN     NaN
