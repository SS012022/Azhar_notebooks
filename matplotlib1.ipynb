# %% [markdown]
# <a href="https://colab.research.google.com/github/SS012022/Azhar_notebooks/blob/main/matplotlib1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

# %%
matplotlib.__version__
# Out:
# '3.7.1'

# %%
# submodule of matplotlib is pyplot
import matplotlib.pyplot as plt
import numpy as np

# %%
#df.plot(x="Team",y="Goals",kind="scatter")
#plt.show()

# %%
x=np.array([0,3,5])
y=np.array([2,4,6])
plt.plot(x,y,marker='o')
plt.show()

# %%
# x : values between 2 to 10 and the gap between numbers should be 2
# y: values between 2 to 4
x=np.arange(2,12,2)
y=np.linspace(2,4,5)
plt.plot(x,y)
#plt.axis("off")
plt.show()

# %%
x=np.arange(2,12,2)
y=np.linspace(2,4,5)
plt.plot(x,y,marker='o')
plt.show()
