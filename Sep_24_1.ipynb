# %% [markdown]
# <a href="https://colab.research.google.com/github/SS012022/Azhar_notebooks/blob/main/Sep_24_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# csv , excel
# comma separated file
# notepad

# %% [markdown]
# roll#name#subject
# 1#qq#java
# 2#rr#python

# %%
import pandas as pd

# %%
df=pd.read_csv("people.csv")
df
# Out:
#    fname   lname address  phone     email  age
# 0     aa    aaaa       t    445  ewrewrew   35
# 1     qq    qqqq       g   8989  dsfdgfdg   25
# 2     ww    wwww       f  21212   dfdfdsf   45
# 3     rr    rrrr       r  78786   wqewqeq   65
# 4     tt    tttt       d    221  gfdgfdgf   75
# 5     yy    yyyy       s   5485  vcbvcbvc   46
# 6     vv    vvvv       q  87963    cxvbvc   59
# 7     dd    dddd       c   3245      wewq   85
# 8     aa  aqaqaq       h   8748     nmnbn   36
# 9     kk    kkkk       y   4552     vcbvb   28
# 10    mm    mmmm       j   2465   ereewre   53

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   fname    11 non-null     object
#  1   lname    11 non-null     object
#  2   address  11 non-null     object
#  3   phone    11 non-null     int64
#  4   email    11 non-null     object
#  5   age      11 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 656.0+ bytes

# %%
df.describe()
# Out:
#               phone        age
# count     11.000000  11.000000
# mean   20191.909091  50.181818
# std    31835.225237  19.327794
# min      221.000000  25.000000
# 25%     2855.000000  35.500000
# 50%     5485.000000  46.000000
# 75%    15100.500000  62.000000
# max    87963.000000  85.000000

# %%
df.describe(percentiles=[.3,.6,.9])
# Out:
#               phone        age
# count     11.000000  11.000000
# mean   20191.909091  50.181818
# std    31835.225237  19.327794
# min      221.000000  25.000000
# 30%     3245.000000  36.000000
# 50%     5485.000000  46.000000
# 60%     8748.000000  53.000000
# 90%    78786.000000  75.000000
# max    87963.000000  85.000000

# %%
df.shape
# Out:
# (11, 6)

# %%
df.columns
# Out:
# Index(['fname', 'lname', 'address', 'phone', 'email', 'age'], dtype='object')

# %%
df1=pd.read_csv("people.csv",usecols=["fname","phone"])
df1
print(df1.head(6))
print(df1.tail(3))
# Out:
#   fname  phone
# 0    aa    445
# 1    qq   8989
# 2    ww  21212
# 3    rr  78786
# 4    tt    221
# 5    yy   5485
#    fname  phone
# 8     aa   8748
# 9     kk   4552
# 10    mm   2465

# %%
df2=pd.read_csv("people.csv",skiprows=[1,3,5])
df2
# Out:
#   fname   lname address  phone     email  age
# 0    qq    qqqq       g   8989  dsfdgfdg   25
# 1    rr    rrrr       r  78786   wqewqeq   65
# 2    yy    yyyy       s   5485  vcbvcbvc   46
# 3    vv    vvvv       q  87963    cxvbvc   59
# 4    dd    dddd       c   3245      wewq   85
# 5    aa  aqaqaq       h   8748     nmnbn   36
# 6    kk    kkkk       y   4552     vcbvb   28
# 7    mm    mmmm       j   2465   ereewre   53

# %%
x=df2["fname"]
x
# Out:
# 0    qq
# 1    rr
# 2    yy
# 3    vv
# 4    dd
# 5    aa
# 6    kk
# 7    mm
# Name: fname, dtype: object

# %%
y=df2.iloc[:,1]
y
# Out:
# 0      qqqq
# 1      rrrr
# 2      yyyy
# 3      vvvv
# 4      dddd
# 5    aqaqaq
# 6      kkkk
# 7      mmmm
# Name: lname, dtype: object

# %%
df3=pd.read_csv("people.csv",header=None)
df3
# Out:
#         0       1        2      3         4    5
# 0   fname   lname  address  phone     email  age
# 1      aa    aaaa        t    445  ewrewrew   35
# 2      qq    qqqq        g   8989  dsfdgfdg   25
# 3      ww    wwww        f  21212   dfdfdsf   45
# 4      rr    rrrr        r  78786   wqewqeq   65
# 5      tt    tttt        d    221  gfdgfdgf   75
# 6      yy    yyyy        s   5485  vcbvcbvc   46
# 7      vv    vvvv        q  87963    cxvbvc   59
# 8      dd    dddd        c   3245      wewq   85
# 9      aa  aqaqaq        h   8748     nmnbn   36
# 10     kk    kkkk        y   4552     vcbvb   28
# 11     mm    mmmm        j   2465   ereewre   53

# %%
df4=pd.read_csv("people.csv")
df4
# Out:
#    fname   lname address  phone     email  age
# 0     aa    aaaa       t    445  ewrewrew   35
# 1     qq    qqqq       g   8989  dsfdgfdg   25
# 2     ww    wwww       f  21212   dfdfdsf   45
# 3     rr    rrrr       r  78786   wqewqeq   65
# 4     tt    tttt       d    221  gfdgfdgf   75
# 5     yy    yyyy       s   5485  vcbvcbvc   46
# 6     vv    vvvv       q  87963    cxvbvc   59
# 7     dd    dddd       c   3245      wewq   85
# 8     aa  aqaqaq       h   8748     nmnbn   36
# 9     kk    kkkk       y   4552     vcbvb   28
# 10    mm    mmmm       j   2465   ereewre   53

# %%
df4.insert(4,"pincode",[123,234,566,777,222,667,888,679,666,435,777])
df4
# Out:
#    fname   lname address  phone  pincode     email  age
# 0     aa    aaaa       t    445      123  ewrewrew   35
# 1     qq    qqqq       g   8989      234  dsfdgfdg   25
# 2     ww    wwww       f  21212      566   dfdfdsf   45
# 3     rr    rrrr       r  78786      777   wqewqeq   65
# 4     tt    tttt       d    221      222  gfdgfdgf   75
# 5     yy    yyyy       s   5485      667  vcbvcbvc   46
# 6     vv    vvvv       q  87963      888    cxvbvc   59
# 7     dd    dddd       c   3245      679      wewq   85
# 8     aa  aqaqaq       h   8748      666     nmnbn   36
# 9     kk    kkkk       y   4552      435     vcbvb   28
# 10    mm    mmmm       j   2465      777   ereewre   53

# %%
df5=df4[df4["age"]>50]
df5
# Out:
#    fname lname address  phone  pincode     email  age
# 3     rr  rrrr       r  78786      777   wqewqeq   65
# 4     tt  tttt       d    221      222  gfdgfdgf   75
# 6     vv  vvvv       q  87963      888    cxvbvc   59
# 7     dd  dddd       c   3245      679      wewq   85
# 10    mm  mmmm       j   2465      777   ereewre   53

# %%
df6=df4.drop(["lname"],axis=1)
df6
#df4.drop(["lname"],axis=1,inplace=True)
#df4
# Out:
#    fname address  phone  pincode     email  age
# 0     aa       t    445      123  ewrewrew   35
# 1     qq       g   8989      234  dsfdgfdg   25
# 2     ww       f  21212      566   dfdfdsf   45
# 3     rr       r  78786      777   wqewqeq   65
# 4     tt       d    221      222  gfdgfdgf   75
# 5     yy       s   5485      667  vcbvcbvc   46
# 6     vv       q  87963      888    cxvbvc   59
# 7     dd       c   3245      679      wewq   85
# 8     aa       h   8748      666     nmnbn   36
# 9     kk       y   4552      435     vcbvb   28
# 10    mm       j   2465      777   ereewre   53

# %%
df4
# Out:
#    fname   lname address  phone  pincode     email  age
# 0     aa    aaaa       t    445      123  ewrewrew   35
# 1     qq    qqqq       g   8989      234  dsfdgfdg   25
# 2     ww    wwww       f  21212      566   dfdfdsf   45
# 3     rr    rrrr       r  78786      777   wqewqeq   65
# 4     tt    tttt       d    221      222  gfdgfdgf   75
# 5     yy    yyyy       s   5485      667  vcbvcbvc   46
# 6     vv    vvvv       q  87963      888    cxvbvc   59
# 7     dd    dddd       c   3245      679      wewq   85
# 8     aa  aqaqaq       h   8748      666     nmnbn   36
# 9     kk    kkkk       y   4552      435     vcbvb   28
# 10    mm    mmmm       j   2465      777   ereewre   53

# %%
df4.drop(["lname"],axis=1,inplace=True)
df4
# Out:
#    fname address  phone     email  age
# 0     aa       t    445  ewrewrew   35
# 1     qq       g   8989  dsfdgfdg   25
# 2     ww       f  21212   dfdfdsf   45
# 3     rr       r  78786   wqewqeq   65
# 4     tt       d    221  gfdgfdgf   75
# 5     yy       s   5485  vcbvcbvc   46
# 6     vv       q  87963    cxvbvc   59
# 7     dd       c   3245      wewq   85
# 8     aa       h   8748     nmnbn   36
# 9     kk       y   4552     vcbvb   28
# 10    mm       j   2465   ereewre   53

# %%
#custom separator
df7=pd.read_csv("stu.csv" , sep="_")
df7
# Out:
#    roll name subject  fee
# 0     1   qq    java  343
# 1     2   ad  python  788
# 2     3   rt    java  689
# 3     4   fg  python  673
# 4     5   ht  python  345
# 5     6   yu    java  678
# 6     7   hj    java  564

# %%
# read the data of students learning java
df2=df7[df7["subject"]=="java"]
df2
# Out:
#    roll name subject  fee
# 0     1   qq    java  343
# 2     3   rt    java  689
# 5     6   yu    java  678
# 6     7   hj    java  564

# %%
df2.columns
# Out:
# Index(['roll', 'name', 'subject', 'fee'], dtype='object')

# %%
df=pd.read_excel("product.xlsx")
df
# Out:
#    prodId prodName  Price unit
# 0     101    maggi    100   pc
# 1     102    sugar    658   kg
# 2     103      tea    475   kg
# 3     104     rice    532   kg
# 4     104   coffee    411   kg

# %%
df1=pd.read_excel("product.xlsx",usecols=[1,2])
df1
# Out:
#   prodName  Price
# 0    maggi    100
# 1    sugar    658
# 2      tea    475
# 3     rice    532
# 4   coffee    411

# %%
import numpy as np

# %%
dict={'Subject':['java','python','html',np.nan],
      'Duration':['45days',np.nan,'30days',np.nan],
      'Fee':[np.nan,122,np.nan,np.nan]}
df=pd.DataFrame(dict)
df
# Out:
#   Subject Duration    Fee
# 0    java   45days    NaN
# 1  python      NaN  122.0
# 2    html   30days    NaN
# 3     NaN      NaN    NaN

# %%
np.count_nonzero(df)
# Out:
# 9

# %%
df.isna().sum()
# Out:
# Subject     0
# Duration    1
# Fee         2
# dtype: int64

# %%
df.fillna('NA',inplace=True)
df
# Out:
# <ipython-input-74-ab2a5adad953>:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value 'NA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.fillna('NA',inplace=True)
#   Subject Duration    Fee
# 0    java   45days     NA
# 1  python       NA  122.0
# 2    html   30days     NA

# %%
df.dropna()
df
# Out:
#   Subject Duration    Fee
# 0    java   45days    NaN
# 1  python      NaN  122.0
# 2    html   30days    NaN

# %%
df["Duration"].fillna("30days",inplace=True)
df
# Out:
#   Subject Duration    Fee
# 0    java   45days    NaN
# 1  python   30days  122.0
# 2    html   30days    NaN

# %%
df.dropna(axis=0,how='any',inplace=True)
df
# Out:
#   Subject Duration    Fee
# 1  python   30days  122.0

# %%
df.dropna(axis=0,how='all',inplace=True)
df
# Out:
#   Subject Duration    Fee
# 0    java   45days    NaN
# 1  python      NaN  122.0
# 2    html   30days    NaN

# %%
df.dropna(axis=1)
# Out:
#   Subject Duration
# 0    java   45days
# 1  python   30days
# 2    html   30days

# %%
dict={'Subject':['java','python','html',np.nan,np.nan],
      'Duration':['45days',np.nan,'30days',np.nan,np.nan],
      'Fee':[np.nan,122,np.nan,np.nan,np.nan],
      'trainer':['a',np.nan,np.nan,'t',np.nan]}
df1=pd.DataFrame(dict)
df1
# Out:
#   Subject Duration    Fee trainer
# 0    java   45days    NaN       a
# 1  python      NaN  122.0     NaN
# 2    html   30days    NaN     NaN
# 3     NaN      NaN    NaN       t
# 4     NaN      NaN    NaN     NaN

# %%
df1.dropna(axis=0,thresh=2,inplace=True) # at least 2 NAN then it will delete the row
df1
# Out:
#   Subject Duration    Fee trainer
# 0    java   45days    NaN       a
# 1  python      NaN  122.0     NaN
# 2    html   30days    NaN     NaN
