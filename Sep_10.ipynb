# %%
import numpy as np

# %%
a=np.arange(1,12,2)
a=a.reshape(3,2)
a
# Out:
# array([[ 1,  3],
#        [ 5,  7],
#        [ 9, 11]])

# %%
b=np.transpose(a)
b
# Out:
# array([[ 1,  5,  9],
#        [ 3,  7, 11]])

# %%
d=np.ndarray.flatten(b)
d
# Out:
# array([ 1,  5,  9,  3,  7, 11])

# %%
e=b.reshape(1,6)
e
# Out:
# array([[ 1,  5,  9,  3,  7, 11]])

# %%
print (b.size)
w=b.reshape(1,b.size)
w
# Out:
# 6
# array([[ 1,  5,  9,  3,  7, 11]])

# %%
q=np.array([3,5,6,2,3,7,5,6,8,5,3,9])
q
# Out:
# array([3, 5, 6, 2, 3, 7, 5, 6, 8, 5, 3, 9])

# %%
t=np.unique(q)
t
# Out:
# array([2, 3, 5, 6, 7, 8, 9])

# %%
p=np.array([1,np.nan,2,4,6,np.nan],dtype=float).reshape(2,3)
p
# Out:
# array([[ 1., nan,  2.],
#        [ 4.,  6., nan]])

# %%
np.count_nonzero(np.isnan(p))
# Out:
# 2

# %%
r=p[np.isnan(p)==False]
r
# Out:
# array([1., 2., 4., 6.])

# %%
r.reshape(2,2)
# Out:
# array([[1., 2.],
#        [4., 6.]])

# %%
a=np.array([3,6,8])
b=np.array([5,8,4])
# SET operation
