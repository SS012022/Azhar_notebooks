# %% [markdown]
# <a href="https://colab.research.google.com/github/SS012022/Azhar_notebooks/blob/main/Sep_19_24.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
a=pd.Series(np.array(['h','e','l','l','0']))
print(a, a.dtype)
# Out:
# 0    h
# 1    e
# 2    l
# 3    l
# 4    0
# dtype: object object

# %%
b=pd.Series(data=[2,5,7,8,9],index=['A','B','C','D','E'],name='Numbers')
b
# Out:
# A    2
# B    5
# C    7
# D    8
# E    9
# Name: Numbers, dtype: int64

# %%
b.ndim
# Out:
# 1

# %%
b.shape
# Out:
# (5,)

# %%
b.dtype
# Out:
# dtype('int64')

# %%
c=pd.Series([3,5,7,5,np.nan,4,7,np.nan])
c
# Out:
# 0    3.0
# 1    5.0
# 2    7.0
# 3    5.0
# 4    NaN
# 5    4.0
# 6    7.0
# 7    NaN
# dtype: float64

# %%
c.size
# Out:
# 8

# %%
c.count() # without NAN
# Out:
# 6

# %%
c.hasnans
# Out:
# True

# %%
d=c.dropna()
d.index=['A','B','C','D','E','F']
d
# Out:
# A    3.0
# B    5.0
# C    7.0
# D    5.0
# E    4.0
# F    7.0
# dtype: float64

# %%
d.tail(2)
# Out:
# E    4.0
# F    7.0
# dtype: float64

# %%
d.head(2)
# Out:
# A    3.0
# B    5.0
# dtype: float64

# %%
d.index
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F'], dtype='object')

# %%
d.values
# Out:
# array([3., 5., 7., 5., 4., 7.])

# %%
d
# Out:
# A    3.0
# B    5.0
# C    7.0
# D    5.0
# E    4.0
# F    7.0
# dtype: float64

# %%
d.nbytes
# Out:
# 48

# %%
d.loc[['D','F']] # get the value of given index ,label name
# Out:
# D    5.0
# F    7.0
# dtype: float64

# %%
d[1:4] # slicing
# Out:
# B    5.0
# C    7.0
# D    5.0
# dtype: float64

# %%
d.iloc[5] # numeric index
# Out:
# 7.0

# %%
d
# Out:
# A    3.0
# B    5.0
# C    7.0
# D    5.0
# E    4.0
# F    7.0
# dtype: float64

# %%
E=d.drop(['B','D'])
E
# Out:
# A    3.0
# C    7.0
# E    4.0
# F    7.0
# dtype: float64

# %%
d.sum()
# Out:
# 31.0

# %%
d.mean()
# Out:
# 5.166666666666667

# %%
d.std()
# Out:
# 1.602081978759722

# %% [markdown]
# **DataFrame**

# %%
A=pd.DataFrame([1,2,3,4])
A
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4

# %%
dc={'First':{'name':'John','Age':34,'mobile':4545},'Second':{'name':'Jimmy','Age':55,'mobile':45655},'Third':{'name':'Jan','Age':32,'mobile':5645}}
B=pd.DataFrame([dc])
B
# Out:
#                                          First  \
# 0  {'name': 'John', 'Age': 34, 'mobile': 4545}
#
#                                           Second  \
# 0  {'name': 'Jimmy', 'Age': 55, 'mobile': 45655}
#
#                                         Third
# 0  {'name': 'Jan', 'Age': 32, 'mobile': 5645}

# %%
dc={'Roll':[10,30,20,34,25,45,67,23],'subject':['java','python','java','java','python','java','java','python']}
C=pd.DataFrame(dc,index=['a','b','c','d','e','f','g','h'])
C
# Out:
#    Roll subject
# a    10    java
# b    30  python
# c    20    java
# d    34    java
# e    25  python
# f    45    java
# g    67    java
# h    23  python

# %%
C.shape
# Out:
# (8, 2)

# %%
C.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, a to h
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Roll     8 non-null      int64
#  1   subject  8 non-null      object
# dtypes: int64(1), object(1)
# memory usage: 192.0+ bytes

# %%
C.ndim
# Out:
# 2

# %%
C.sum()
# Out:
# Roll                                          254
# subject    javapythonjavajavapythonjavajavapython
# dtype: object

# %%
C.columns
# Out:
# Index(['Roll', 'subject'], dtype='object')

# %%
C['phone']=[23,55,66,73,35,86,33,85]
C
# Out:
#    Roll subject  phone
# a    10    java     23
# b    30  python     55
# c    20    java     66
# d    34    java     73
# e    25  python     35
# f    45    java     86
# g    67    java     33
# h    23  python     85

# %%
D=C[['Roll','phone']]
D
# Out:
#    Roll  phone
# a    10     23
# b    30     55
# c    20     66
# d    34     73
# e    25     35
# f    45     86
# g    67     33
# h    23     85

# %%
D.tail(4)
# Out:
#    Roll  phone
# e    25     35
# f    45     86
# g    67     33
# h    23     85

# %%
D.head(5)
# Out:
#    Roll  phone
# a    10     23
# b    30     55
# c    20     66
# d    34     73
# e    25     35

# %%
D[D['phone']>55]
# Out:
#    Roll  phone
# c    20     66
# d    34     73
# f    45     86
# h    23     85

# %%
D[2:5]
# Out:
#    Roll  phone
# c    20     66
# d    34     73
# e    25     35

# %%
D.loc[2,'phone']
# Out:
# 66

# %%
D.loc['b','Roll']
# Out:
# 30

# %%
D.iloc[2:4,1]
# Out:
# c    66
# d    73
# Name: phone, dtype: int64

# %%
D.loc[['c','d'],'phone']
# Out:
# c    66
# d    73
# Name: phone, dtype: int64

# %%
D.sum(axis=1)
# Out:
# a     33
# b     85
# c     86
# d    107
# e     60
# f    131
# g    100
# h    108
# dtype: int64

# %%
E=D[D['phone']>55]
E
# Out:
#    Roll  phone
# c    20     66
# d    34     73
# f    45     86
# h    23     85

# %%
D.mean(axis=1)
# Out:
# a    16.5
# b    42.5
# c    43.0
# d    53.5
# e    30.0
# f    65.5
# g    50.0
# h    54.0
# dtype: float64

# %%
D.describe()
# Out:
#             Roll      phone
# count   8.000000   8.000000
# mean   31.750000  57.000000
# std    17.564168  24.442352
# min    10.000000  23.000000
# 25%    22.250000  34.500000
# 50%    27.500000  60.500000
# 75%    36.750000  76.000000
# max    67.000000  86.000000

# %%
D.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, a to h
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Roll    8 non-null      int64
#  1   phone   8 non-null      int64
# dtypes: int64(2)
# memory usage: 492.0+ bytes
